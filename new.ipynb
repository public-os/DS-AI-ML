# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# x=np.array([1,2,3,4,5])
# y=np.array([2,3,5,7,11])
# plt.plot(x,y)

std_hour=np.array([4,5,6,7,8,9,10])
marks=np.array([60,65,70,75,80,85,90])
plt.plot(std_hour,marks)
# plt.xlabel('x-axis')
# plt.ylabel('y-axis')
# plt.title('Simple Plot')
